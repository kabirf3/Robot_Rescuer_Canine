# %%
# Fahmida Kabir 
# Last Updated: 12.06/2025
# This specific file works on the facial recognition aspect for the robot canine, there are a lot of goals that the facial recognition will have to do, due to the time and speciality needed YOLO will be used.

# %%
# Installing libraries required for teh YOLO 5 to work 

#!pip install torch torchvision torchaudio
#!pip install opencv-python pandas

# %%
# This is the repositirie for the YOLO5 so i can use it

#!git clone https://github.com/ultralytics/yolov5.git
#%cd yolov5
# Out:
# c:\Final_Project\Robot_Rescuer_Canine\yolov5
# Cloning into 'yolov5'...

# %%
# Installing dependecies 

# !pip install -r requirements.txt

# %%
# Now in this part  I am going to import the libraries that are going to be used in this code 

import torch
import cv2
from yolov5 import detect
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26124\2403903591.py in <module>
#       3 import torch
#       4 import cv2
# ----> 5 from yolov5 import detect
#
# c:\Final_Project\Robot_Rescuer_Canine\yolov5\detect.py in <module>
#      46 from ultralytics.utils.plotting import Annotator, colors, save_one_box
#      47
# ---> 48 from models.common import DetectMultiBackend
#      49 from utils.dataloaders import IMG_FORMATS, VID_FORMATS, LoadImages, LoadScreenshots, LoadStreams
#      50 from utils.general import (
#
# C:\Final_Project\Robot_Rescuer_Canine\yolov5\models\common.py in <module>
#      37
#      38 from utils import TryExcept
# ---> 39 from utils.dataloaders import exif_transpose, letterbox
#      40 from utils.general import (
#      41     LOGGER,
#
# C:\Final_Project\Robot_Rescuer_Canine\yolov5\utils\dataloaders.py in <module>
# ...

# %%
import os
import sys

print(os.getcwd())
# Out:
# c:\Final_Project\Robot_Rescuer_Canine

# %%
import tarfile
print(tarfile.__file__)
# Out:
# c:\Users\saazk\anaconda3\lib\tarfile.py

# %%
print(os.listdir("yolov5"))

import sys
sys.path.append(os.path.abspath("yolov5"))  # Add yolov5 to system path

# Import detect.py as a module
import detect

# Run YOLOv5 detection
detect.run(weights="yolov5s.pt", source="image.jpg") 

import backports
print(backports.__file__)
# Out:
# ['.dockerignore', '.git', '.gitattributes', '.github', '.gitignore', 'benchmarks.py', 'CITATION.cff', 'classify', 'CONTRIBUTING.md', 'data', 'detect.py', 'export.py', 'hubconf.py', 'LICENSE', 'models', 'pyproject.toml', 'README.md', 'README.zh-CN.md', 'requirements.txt', 'segment', 'train.py', 'tutorial.ipynb', 'utils', 'val.py', '__pycache__']
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26124\1723679135.py in <module>
#       5
#       6 # Import detect.py as a module
# ----> 7 import detect
#       8
#       9 # Run YOLOv5 detection
#
# C:\Final_Project\Robot_Rescuer_Canine\yolov5\detect.py in <module>
#      46 from ultralytics.utils.plotting import Annotator, colors, save_one_box
#      47
# ---> 48 from models.common import DetectMultiBackend
# ...
